# %% [markdown]
# ### Creating and collecting data in pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv', index_col='ResponseId')

# %%
df.shape
# Out:
# (65437, 113)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65437 entries, 1 to 65437
# Columns: 113 entries, MainBranch to JobSat
# dtypes: float64(13), object(100)
# memory usage: 56.9+ MB

# %%
pd.set_option('display.max_columns',114)

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
schema_df=pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %%
pd.set_option('display.max_rows',87)

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID2            MainBranch
# 1   QID127                   Age
# 2   QID296            Employment
# 3   QID308            RemoteWork
# 4   QID341                 Check
# 5   QID297      CodingActivities
# 6    QID25               EdLevel
# 7   QID276             LearnCode
# 8   QID281       LearnCodeOnline
# 9   QID331               TechDoc
# 10   QID32             YearsCode
# 11   QID34          YearsCodePro
# 12   QID31               DevType
# 13   QID29               OrgSize
# 14  QID278     PurchaseInfluence
# 15  QID279            BuyNewTool
# 16  QID330            BuildvsBuy
# 17  QID335           TechEndorse
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21  QID233              Language
# 22  QID262              Database
# 23  QID263              Platform
# 24  QID264              Webframe
# 25  QID340              Embedded
# 26  QID265              MiscTech
# ...

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
df.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
# 9                                 I code primarily as a hobby
# 10                             I am a developer by profession
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 2              35-44 years old
# 3              45-54 years old
# 4              18-24 years old
# 5              18-24 years old
# 6           Under 18 years old
# ...

# %%
df.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
# 9                                 I code primarily as a hobby
# 10                             I am a developer by profession
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 2              35-44 years old
# 3              45-54 years old
# 4              18-24 years old
# 5              18-24 years old
# 6           Under 18 years old
# ...

# %%
df.shape
# Out:
# (65437, 113)

# %%
df['CodingActivities'].value_counts()
# Out:
# CodingActivities
# Hobby                                                                                                                                                                              9993
# I don’t code outside of work                                                                                                                                                       6508
# Hobby;Professional development or self-paced learning from online courses                                                                                                          6203
# Hobby;Contribute to open-source projects                                                                                                                                           3732
# Professional development or self-paced learning from online courses                                                                                                                3120
# ...

# %%
df.loc[[1,12],['MainBranch','CodingActivities']]
# Out:
#                                 MainBranch               CodingActivities
# ResponseId
# 1           I am a developer by profession                          Hobby
# 12          I am a developer by profession  Hobby;School or academic work

# %%
df.loc[1:12,['MainBranch','CodingActivities']]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
# 9                                 I code primarily as a hobby
# 10                             I am a developer by profession
# 11          I used to be a developer by profession, but no...
# 12                             I am a developer by profession
#
#                                              CodingActivities
# ResponseId
# 1                                                       Hobby
# ...

# %%
df.loc[3:20,'CodingActivities':]
# Out:
#                                              CodingActivities  \
# ResponseId
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 7                                I don’t code outside of work
# 8                                                         NaN
# 9                                                       Hobby
# 10                                   Bootstrapping a business
# 11                   Hobby;Contribute to open-source projects
# 12                              Hobby;School or academic work
# 13          Hobby;Contribute to open-source projects;Profe...
# 14                                                        NaN
# 15          Hobby;Professional development or self-paced l...
# 16                                                      Hobby
# ...

# %%
df.loc[2]
# Out:
# MainBranch             I am a developer by profession
# Age                                   35-44 years old
# Employment                        Employed, full-time
# RemoteWork                                     Remote
# Check                                          Apples
#                                     ...
# JobSatPoints_11                                   0.0
# SurveyLength                                      NaN
# SurveyEase                                        NaN
# ConvertedCompYearly                               NaN
# JobSat                                            NaN
# Name: 2, Length: 113, dtype: object

# %%
pd.set_option('display.max_columns',114)

# %%
df.loc[2]
# Out:
# MainBranch             I am a developer by profession
# Age                                   35-44 years old
# Employment                        Employed, full-time
# RemoteWork                                     Remote
# Check                                          Apples
#                                     ...
# JobSatPoints_11                                   0.0
# SurveyLength                                      NaN
# SurveyEase                                        NaN
# ConvertedCompYearly                               NaN
# JobSat                                            NaN
# Name: 2, Length: 113, dtype: object

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID2            MainBranch
# 1   QID127                   Age
# 2   QID296            Employment
# 3   QID308            RemoteWork
# 4   QID341                 Check
# 5   QID297      CodingActivities
# 6    QID25               EdLevel
# 7   QID276             LearnCode
# 8   QID281       LearnCodeOnline
# 9   QID331               TechDoc
# 10   QID32             YearsCode
# 11   QID34          YearsCodePro
# 12   QID31               DevType
# 13   QID29               OrgSize
# 14  QID278     PurchaseInfluence
# 15  QID279            BuyNewTool
# 16  QID330            BuildvsBuy
# 17  QID335           TechEndorse
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21  QID233              Language
# 22  QID262              Database
# 23  QID263              Platform
# 24  QID264              Webframe
# 25  QID340              Embedded
# 26  QID265              MiscTech
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID2            MainBranch
# 1   QID127                   Age
# 2   QID296            Employment
# 3   QID308            RemoteWork
# 4   QID341                 Check
# 5   QID297      CodingActivities
# 6    QID25               EdLevel
# 7   QID276             LearnCode
# 8   QID281       LearnCodeOnline
# 9   QID331               TechDoc
# 10   QID32             YearsCode
# 11   QID34          YearsCodePro
# 12   QID31               DevType
# 13   QID29               OrgSize
# 14  QID278     PurchaseInfluence
# 15  QID279            BuyNewTool
# 16  QID330            BuildvsBuy
# 17  QID335           TechEndorse
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21  QID233              Language
# 22  QID262              Database
# 23  QID263              Platform
# 24  QID264              Webframe
# 25  QID340              Embedded
# 26  QID265              MiscTech
# ...

# %%
schema_df.set_index('qname',inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# Check                 QID341
# CodingActivities      QID297
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# TechDoc               QID331
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# BuildvsBuy            QID330
# TechEndorse           QID335
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# Embedded              QID340
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# OpSys                  QID71
# ...

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
schema_df.loc['TechDoc','question']
# Out:
# 'What is the source of the technical documentation you use most often to learn to code?  Select all that apply.'

# %%
schema_df.sort_index(ascending=False)
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TechEndorse           QID335
# TechDoc               QID331
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOHow                 QID334
# SOComm                QID106
# SOAccount             QID101
# RemoteWork            QID308
# PurchaseInfluence     QID278
# ProfessionalTech      QID304
# ProfessionalQuestion  QID333
# ProfessionalCloud     QID332
# Platform              QID263
# OrgSize                QID29
# OpSys                  QID71
# OfficeStackSync       QID307
# OfficeStackAsync      QID282
# NEWSOSites            QID266
# NEWCollabTools        QID274
# ...

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
filt=(df['Age']=='Under 18 years old') | (df['LearnCode']=='Primary/elementary school')

# %%
filt
# Out:
# ResponseId
# 1         True
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 65433    False
# 65434    False
# 65435    False
# 65436    False
# 65437    False
# Length: 65437, dtype: bool

# %%
df[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 17                                I code primarily as a hobby
# 35                                I code primarily as a hobby
# 40                             I am a developer by profession
# ...                                                       ...
# 65234       I am not primarily a developer, but I write co...
# 65278                                   I am learning to code
# 65387                             I code primarily as a hobby
# 65421                                   I am learning to code
# 65427                                   I am learning to code
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 6           Under 18 years old
# 17          Under 18 years old
# 35          Under 18 years old
# 40          Under 18 years old
# ...

# %%
df.loc[filt,['MainBranch','EdLevel']]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 17                                I code primarily as a hobby
# 35                                I code primarily as a hobby
# 40                             I am a developer by profession
# ...                                                       ...
# 65234       I am not primarily a developer, but I write co...
# 65278                                   I am learning to code
# 65387                             I code primarily as a hobby
# 65421                                   I am learning to code
# 65427                                   I am learning to code
#
#                                                       EdLevel
# ResponseId
# 1                                   Primary/elementary school
# 6                                   Primary/elementary school
# ...

# %%
pd.set_option('display.max_columns',200)

# %%
df.loc[filt,['MainBranch','EdLevel']]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 17                                I code primarily as a hobby
# 35                                I code primarily as a hobby
# 40                             I am a developer by profession
# ...                                                       ...
# 65234       I am not primarily a developer, but I write co...
# 65278                                   I am learning to code
# 65387                             I code primarily as a hobby
# 65421                                   I am learning to code
# 65427                                   I am learning to code
#
#                                                       EdLevel
# ResponseId
# 1                                   Primary/elementary school
# 6                                   Primary/elementary school
# ...

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
filt2= df['EdLevel'].str.contains(' B.Eng.',' B.S.', na=False)

# %%
df.loc[filt2]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 11          I used to be a developer by profession, but no...
# 13                             I am a developer by profession
# 14          I used to be a developer by profession, but no...
# 18                             I am a developer by profession
# ...                                                       ...
# 65418                          I am a developer by profession
# 65429                          I am a developer by profession
# 65432                          I am a developer by profession
# 65433                          I am a developer by profession
# 65435                          I am a developer by profession
#
#                         Age  \
# ResponseId
# 2           35-44 years old
# 11          35-44 years old
# 13          35-44 years old
# 14          35-44 years old
# 18          18-24 years old
# ...
